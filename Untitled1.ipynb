# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/cxnfs/Mark/Data/cleaned_data/pm25_cleaned.csv', index_col = 0, parse_dates = True)

# %%
df
# Out:
#                       PM2.5 (µg/m^3)
# 2019-12-28 06:50:00            9.791
# 2019-12-28 06:51:00           10.541
# 2019-12-28 06:52:00           10.000
# 2019-12-28 06:53:00            8.733
# 2019-12-28 06:54:00            7.325
# ...                              ...
# 2020-07-09 03:32:53            8.500
# 2020-07-09 03:33:54            9.300
# 2020-07-09 03:34:53            9.100
# 2020-07-09 03:35:53            7.900
# 2020-07-09 03:36:53           11.700
#
# [248153 rows x 1 columns]

# %%
df['02-07-2020':'02-07-2020'].iloc[:,0].plot(color = 'black')
plt.ylim(0,200)
# Out:
# (0.0, 200.0)

# %%
df['04-01-2020':'04-01-2020'].iloc[:,0].plot(color = 'black')
plt.ylim(0,200)
# Out:
# (0.0, 200.0)
