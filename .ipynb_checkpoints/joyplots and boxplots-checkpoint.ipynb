# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_orig = pd.read_csv(r'/cxnfs/Mark/Data/complete_data.csv', index_col = 0, parse_dates =  True)

# %%
df_orig[[' PM10 (µg/m^3)', ' PM2.5 (µg/m^3)', ' PM1 (µg/m^3)']].describe()
# Out:
#         PM10 (µg/m^3)   PM2.5 (µg/m^3)   PM1 (µg/m^3)
# count   248171.000000    248171.000000  248171.000000
# mean        16.277031        13.120716      11.315146
# std         22.290424        11.080843       9.747115
# min          0.300000         0.300000       0.300000
# 25%          7.200000         6.000000       4.900000
# 50%         12.500000        10.100000       8.600000
# 75%         20.600000        16.600000      14.400000
# max       7910.000000      1006.700000     237.200000

# %%
# pd.read_csv(path+'pm10_cleaned.csv')

# %%
prepandemic_data.dropna().wind_dir.describe()
# Out:
# count    54645.000000
# mean       119.346904
# std        119.045261
# min          0.000000
# 25%          0.000000
# 50%         99.000000
# 75%        218.000000
# max        359.001000
# Name: wind_dir, dtype: float64

# %%
prepandemic_data.dropna().windspeed.describe()
# Out:
# count    54645.000000
# mean         0.521634
# std          0.591976
# min          0.000000
# 25%          0.000000
# 50%          0.413000
# 75%          0.765000
# max          6.673000
# Name: windspeed, dtype: float64

# %%
ecq_data.dropna().windspeed.describe().to_fraem().style.to_latex()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ecq_data.dropna().windspeed.describe().style.to_latex()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'style'

# %%
ecq_data.dropna().wind_dir.describe()
# Out:
# count    85854.000000
# mean       108.608370
# std        114.727218
# min          0.000000
# 25%          0.000000
# 50%         80.000000
# 75%        191.000000
# max        359.001000
# Name: wind_dir, dtype: float64

# %%
path = r'/cxnfs/Mark/Data/cleaned_data/'
df = pd.read_csv(r'/cxnfs/Mark/Data/complete_data.csv', index_col = 0, parse_dates =  True)
#cleaned data
pm10 = pd.read_csv(path+'pm10_cleaned.csv', index_col = 0, parse_dates = True)
pm25 = pd.read_csv(path+'pm25_cleaned.csv', index_col = 0, parse_dates = True)
pm1 = pd.read_csv(path+'pm1_cleaned.csv', index_col = 0, parse_dates = True)
#storing PM data in a dataframe along with other variables
data = pd.DataFrame()
data.index = df.index
data['pm10'] = pm10.iloc[:,0]
data['pm25'] = pm25.iloc[:,0]
data['pm1'] = pm1.iloc[:,0]
data['windspeed'] = df[' Windspeed (m/s)']
data['wind_dir'] = df[' WindDirect (Degr)']
prepandemic_data = data['2020-02-01':'2020-03-09']
prepandemic_data = prepandemic_data.dropna(how = 'any', axis = 'rows')
# #classes were suspended last March 10, 2020 to March 14, 2020
ecq_data = data['2020-03-17':'2020-05-15'] #start of lockdown until end of ECQ
ecq_data = ecq_data.dropna(how = 'any', axis = 'rows')

# %%
prepandemic_data[['pm25']].groupby(by = prepandemic_data.index.day_of_week).boxplot(rot = 90, figsize = (8,6), subplots = False)
for n in range(1,7):
    plt.text(n,140, 'hello')

# %%
prepandemic_data[['pm25']].groupby(by = prepandemic_data.index.day_of_week).boxplot(rot = 90, figsize = (8,6), subplots = False)
# Out:
# <AxesSubplot:>

# %%
prepandemic_data[['pm25']].groupby(by = prepandemic_data.index.hour).boxplot(subplots = False, figsize = (8,6), rot = 90)
# Out:
# <AxesSubplot:>

# %%
ecq_data[['windspeed']].groupby(by = ecq_data.index.hour).boxplot(subplots = False, rot = 0)
plt.xticks(np.arange(1,25), np.arange(0,24))
plt.ylabel('$wind~speed~(m/s)$')
plt.xlabel('Hour of the day')
plt.ylim(0,7)
plt.show()

# %%
prepandemic_data[['windspeed']].groupby(by = prepandemic_data.index.hour).boxplot(subplots = False, rot = 0)
plt.xticks(np.arange(1,25), np.arange(0,24))
plt.ylabel('$wind~speed~(m/s)$')
plt.xlabel('Hour of the day')
plt.ylim(0,7)
plt.show()

# %%
prepandemic_data[['pm10']].max()
# Out:
# pm10    213.1
# dtype: float64

# %% [markdown]
# ## Prepandemic PM10 hourly boxplots

# %%
prepandemic_data[['pm10']].groupby(by = prepandemic_data.index.hour).boxplot(subplots = False, rot = 0)
plt.xticks(np.arange(1,25), np.arange(0,24))
plt.ylabel('$PM_{10}~(\mu g/m^3)$')
plt.xlabel('Hour of the day')
plt.ylim(-2,220)
plt.show()

# %% [markdown]
# ## Pandemic PM10 hourly boxplots

# %%
ecq_data[['pm10']].max()
# Out:
# pm10    150.7
# dtype: float64

# %%
ecq_data[['pm10']].groupby(by = ecq_data.index.hour).boxplot(subplots = False, rot = 0)
plt.xticks(np.arange(1,25), np.arange(0,24))
plt.ylabel('$PM_{10}~(\mu g/m^3)$')
plt.xlabel('Hour of the day')
plt.ylim(-2,220)
plt.show()

# %% [markdown]
# ## Prepandemic PM2.5 hourly boxplots

# %%
prepandemic_data[['pm25']].max()
# Out:
# pm25    145.6
# dtype: float64

# %%
prepandemic_data[['pm25']].groupby(by = prepandemic_data.index.hour).boxplot(subplots = False, rot = 0)
plt.xticks(np.arange(1,25), np.arange(0,24))
plt.ylabel('$PM_{2.5}~(\mu g/m^3)$')
plt.xlabel('Hour of the day')
plt.ylim(-2,150)
plt.show()

# %% [markdown]
# ## Pandemic PM2.5 hourly boxplots

# %%
ecq_data[['pm25']].max()
# Out:
# pm25    144.2
# dtype: float64

# %%
ecq_data[['pm25']].groupby(by = ecq_data.index.hour).boxplot(subplots = False, rot = 0)
plt.xticks(np.arange(1,25), np.arange(0,24))
plt.ylabel('$PM_{2.5}~(\mu g/m^3)$')
plt.xlabel('Hour of the day')
plt.ylim(-2,150)
plt.show()

# %% [markdown]
# ## prepandemic pm1 hourly boxplots

# %%
prepandemic_data[['pm1']].max()
# Out:
# pm1    141.2
# dtype: float64

# %%
prepandemic_data[['pm1']].groupby(by = prepandemic_data.index.hour).boxplot(subplots = False, rot = 0)
plt.xticks(np.arange(1,25), np.arange(0,24))
plt.ylabel('$PM_{1}~(\mu g/m^3)$')
plt.xlabel('Hour of the day')
plt.ylim(-2,145)
plt.show()

# %%
ecq_data[['pm1']].max()
# Out:
# pm1    130.3
# dtype: float64

# %%
ecq_data[['pm1']].groupby(by = ecq_data.index.hour).boxplot(subplots = False, rot = 0)
plt.xticks(np.arange(1,25), np.arange(0,24))
plt.ylabel('$PM_{1}~(\mu g/m^3)$')
plt.xlabel('Hour of the day')
plt.ylim(-2,145)
plt.show()

# %%
np.arange(1,25).shape
# Out:
# (24,)

# %%
prepandemic_data[['pm10']].groupby(by = prepandemic_data.index.hour).boxplot(subplots = False, figsize = (8,6), rot = 90)
# Out:
# <AxesSubplot:>

# %%
ecq_data[['pm25']].groupby(by = ecq_data.index.hour).boxplot(subplots = False, figsize = (8,6), rot = 90)
# Out:
# <AxesSubplot:>

# %%
ecq_data[['pm1']].groupby(by = ecq_data.index.hour).boxplot(subplots = False, figsize = (8,6), rot = 90)
# Out:
# <AxesSubplot:>

# %%
ecq_data[['pm10']].groupby(by = ecq_data.index.hour).boxplot(subplots = False, figsize = (8,6), rot = 90)
# Out:
# <AxesSubplot:>

# %%
#creating new dataframes to acount for all seconds in its index
prepandemic_data_1 = pd.DataFrame(columns = ['pm10', 'pm25', 'pm1'], index = pd.date_range('2020-02-01 00:00:00', '2020-03-09 23:59:59', freq = 's'))
ecq_data_1 = pd.DataFrame(columns = ['pm10', 'pm25', 'pm1'], index = pd.date_range('2020-03-15 00:00:00', '2020-05-15 15:59:59', freq = 's'))

for col in ['pm10', 'pm25', 'pm1']:
    prepandemic_data_1[col]  = prepandemic_data[col]
    ecq_data_1[col] = ecq_data[col]

# %%
#creating dataframes such that index refer to seconds and columns refer to a particular day
prepandemic_day_pm25_df = pd.DataFrame(columns = ['Feb_'+ str(n) for n in np.arange(1, 30)]+['Mar_'+str(m) for m in range(1, 10)], index = np.arange(1, (24*60*60)+1, 1))
prepandemic_day_pm10_df = pd.DataFrame(columns = ['Feb_'+ str(n) for n in np.arange(1, 30)]+['Mar_'+str(m) for m in range(1, 10)], index = np.arange(1, (24*60*60)+1, 1))
prepandemic_day_pm1_df = pd.DataFrame(columns = ['Feb_'+ str(n) for n in np.arange(1, 30)]+['Mar_'+str(m) for m in range(1, 10)], index = np.arange(1, (24*60*60)+1, 1))

# %%
for day in np.arange(1, 30, 1):
    prepandemic_day_pm25_df['Feb_'+str(day)] = prepandemic_data_1.pm25['2020-02-'+str(day):'2020-02-'+str(day)].to_numpy()
for day in np.arange(1, 10,1):
    prepandemic_day_pm25_df['Mar_'+str(day)] = prepandemic_data_1.pm25['2020-03-'+str(day):'2020-03-'+str(day)].to_numpy()
    
for day in np.arange(1, 30, 1):
    prepandemic_day_pm10_df['Feb_'+str(day)] = prepandemic_data_1.pm10['2020-02-'+str(day):'2020-02-'+str(day)].to_numpy()
for day in np.arange(1, 10,1):
    prepandemic_day_pm10_df['Mar_'+str(day)] = prepandemic_data_1.pm10['2020-03-'+str(day):'2020-03-'+str(day)].to_numpy()
    
for day in np.arange(1, 30, 1):
    prepandemic_day_pm1_df['Feb_'+str(day)] = prepandemic_data_1.pm1['2020-02-'+str(day):'2020-02-'+str(day)].to_numpy()
for day in np.arange(1, 10,1):
    prepandemic_day_pm1_df['Mar_'+str(day)] = prepandemic_data_1.pm1['2020-03-'+str(day):'2020-03-'+str(day)].to_numpy()

# %%
ecq_day_pm25_df = pd.DataFrame(columns = ['Mar_'+str(m) for m in range(15, 32)] + ['Apr_'+str(m) for m in range(1, 31)] + ['May_'+str(m) for m in range(1, 16)], index = np.arange(1, (24*60*60)+1, 1))
ecq_day_pm10_df = pd.DataFrame(columns = ['Mar_'+str(m) for m in range(15, 32)] + ['Apr_'+str(m) for m in range(1, 31)] + ['May_'+str(m) for m in range(1, 16)], index = np.arange(1, (24*60*60)+1, 1))
ecq_day_pm1_df = pd.DataFrame(columns = ['Mar_'+str(m) for m in range(15, 32)] + ['Apr_'+str(m) for m in range(1, 31)] + ['May_'+str(m) for m in range(1, 16)], index = np.arange(1, (24*60*60)+1, 1))

# %%
for day in np.arange(15, 32, 1):
    ecq_day_pm25_df['Mar_'+str(day)] = ecq_data_1.pm25['2020-03-'+str(day):'2020-03-'+str(day)].to_numpy()
for day in np.arange(1, 31,1):
    ecq_day_pm25_df['Apr_'+str(day)] = ecq_data_1.pm25['2020-04-'+str(day):'2020-04-'+str(day)].to_numpy()
for day in np.arange(1, 15,1):
    ecq_day_pm25_df['May_'+str(day)] = ecq_data_1.pm25['2020-05-'+str(day):'2020-05-'+str(day)].to_numpy()
    

for day in np.arange(15, 32, 1):
    ecq_day_pm10_df['Mar_'+str(day)] = ecq_data_1.pm10['2020-03-'+str(day):'2020-03-'+str(day)].to_numpy()
for day in np.arange(1, 31,1):
    ecq_day_pm10_df['Apr_'+str(day)] = ecq_data_1.pm10['2020-04-'+str(day):'2020-04-'+str(day)].to_numpy()
for day in np.arange(1, 15,1):
    ecq_day_pm10_df['May_'+str(day)] = ecq_data_1.pm10['2020-05-'+str(day):'2020-05-'+str(day)].to_numpy()
    
for day in np.arange(15, 32, 1):
    ecq_day_pm1_df['Mar_'+str(day)] = ecq_data_1.pm1['2020-03-'+str(day):'2020-03-'+str(day)].to_numpy()
for day in np.arange(1, 31,1):
    ecq_day_pm1_df['Apr_'+str(day)] = ecq_data_1.pm1['2020-04-'+str(day):'2020-04-'+str(day)].to_numpy()
for day in np.arange(1, 15,1):
    ecq_day_pm1_df['May_'+str(day)] = ecq_data_1.pm1['2020-05-'+str(day):'2020-05-'+str(day)].to_numpy()

# %%
for col in prepandemic_day_pm25_df.columns:
    prepandemic_day_pm25_df[col] = prepandemic_day_pm25_df[col].apply(lambda x: (x-prepandemic_day_pm25_df[col].min()) / (prepandemic_day_pm25_df[col].max() - prepandemic_day_pm25_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)
    
for col in prepandemic_day_pm10_df.columns:
    prepandemic_day_pm10_df[col] = prepandemic_day_pm10_df[col].apply(lambda x: (x-prepandemic_day_pm10_df[col].min()) / (prepandemic_day_pm10_df[col].max() - prepandemic_day_pm10_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)

for col in prepandemic_day_pm1_df.columns:
    prepandemic_day_pm1_df[col] = prepandemic_day_pm1_df[col].apply(lambda x: (x-prepandemic_day_pm1_df[col].min()) / (prepandemic_day_pm1_df[col].max() - prepandemic_day_pm1_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)

# %%
for col in ecq_day_pm25_df.columns:
    ecq_day_pm25_df[col] = ecq_day_pm25_df[col].apply(lambda x: (x-ecq_day_pm25_df[col].min()) / (ecq_day_pm25_df[col].max() - ecq_day_pm25_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)
    
for col in ecq_day_pm10_df.columns:
    ecq_day_pm10_df[col] = ecq_day_pm10_df[col].apply(lambda x: (x-ecq_day_pm10_df[col].min()) / (ecq_day_pm10_df[col].max() - ecq_day_pm10_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)

for col in ecq_day_pm1_df.columns:
    ecq_day_pm1_df[col] = ecq_day_pm1_df[col].apply(lambda x: (x-ecq_day_pm1_df[col].min()) / (ecq_day_pm1_df[col].max() - ecq_day_pm1_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)

# %%
# Feb_wk1 = prepandemic_data['2020-02-01':'2020-02-07'] #Saturday to Friday
# Feb_wk2 = prepandemic_data['2020-02-08':'2020-02-14']
# Feb_wk3 = prepandemic_data['2020-02-15':'2020-02-21']
# Feb_wk4 = prepandemic_data['2020-02-22':'2020-02-28']
# March_wk1 = prepandemic_data['2020-02-29':'2020-03-06']

# for col in ['pm10', 'pm25', 'pm1']:
#     Feb_wk1[col] = Feb_wk1[col].apply(lambda x: (x - Feb_wk1[col].min())/(Feb_wk1[col].max() - Feb_wk1[col].min()))
#     Feb_wk2[col] = Feb_wk2[col].apply(lambda x: (x - Feb_wk2[col].min())/(Feb_wk2[col].max() - Feb_wk2[col].min()))
#     Feb_wk3[col] = Feb_wk3[col].apply(lambda x: (x - Feb_wk3[col].min())/(Feb_wk3[col].max() - Feb_wk3[col].min()))
#     Feb_wk4[col] = Feb_wk4[col].apply(lambda x: (x - Feb_wk4[col].min())/(Feb_wk4[col].max() - Feb_wk4[col].min()))
#     March_wk1[col] = March_wk1[col].apply(lambda x: (x - March_wk1[col].min())/(March_wk1[col].max() - March_wk1[col].min()))

# %%
# ratio_to_peak_df = pd.DataFrame(columns = ['Feb_'+ str(n) for n in np.arange(1, 30)]+['Mar_'+str(m) for m in range(1, 10)], index = np.arange(1, (24*60*60)+1, 1))

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# x=np.linspace(-10,10,21)
# y=np.linspace(-10,10,21)
# X,Y=np.meshgrid(x,y)

# #synthetic data
# x_c=(x[0:-1]+x[1:])*0.5#center of each cell
# y_c=(y[0:-1]+y[1:])*0.5
# Xc,Yc=np.meshgrid(x_c,y_c)
# Z=Xc**2+Yc**2

# #values in those cells without data are set as np.nan
# Z[9:11,9]=np.nan
# Z[0,0:3]=np.nan
# Z[3:4,0]=np.nan

# #plot the data
# fig=plt.figure()
# plt.pcolor(X,Y,Z)
# plt.show()

# %%
# pm2.5 -- prepandemic peak and min time of the day
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(0,39)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,prepandemic_day_pm25_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5, 39.5, 3), ['Day '+ str(n) for n in np.arange(1, 40,3)])
cbar.ax.set_ylabel('$PM_{2.5}$ (normalized)')
plt.show()

# %%
# pm2.5 -- ecq peak and min time of the day
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(63)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,ecq_day_pm25_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5, 64, 4), ['Day '+ str(n) for n in np.arange(1, 64,4)])
cbar.ax.set_ylabel('$PM_{2.5}$ (normalized)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 # pm2.5 -- ecq peak and min time of the day
# ----> 2 x_bin = np.arange(0, (24*60*60)+1, 1)
#       3 y_bin = np.arange(63)
#       4 X, Y = np.meshgrid(x_bin, y_bin)
#
# NameError: name 'np' is not defined

# %%
#pm2.5 total
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(101)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,np.vstack((prepandemic_day_pm25_df.T,ecq_day_pm25_df.T)), cmap = 'magma_r')
cbar = plt.colorbar(c)
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5,101.5,11), ['Day '+ str(n) for n in np.arange(1, 102,11)])
plt.hlines(39, 0, 24, color = 'blue', linestyle = 'dashed')
cbar.ax.set_ylabel('$PM_{2.5}$ (normalized)')
plt.show()

# %%
np.arange(0, (24*60*60)+1, 1)
# Out:
# array([    0,     1,     2, ..., 86398, 86399, 86400])

# %%
# pm1 -- prepandemic peak and min time of the day
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(39)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,prepandemic_day_pm1_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5, 39.5, 3), ['Day '+ str(n) for n in np.arange(1, 40,3)])
# cbar.ax.set_ylabel('$PM_{1}$ (normalized)')
plt.xlabel('Hour of day')
plt.grid()
plt.show()

# %%
pd.Series.plot.box?
# Out:
# Signature: pd.Series.plot.box(self, by=None, **kwargs)
# Docstring:
# Make a box plot of the DataFrame columns.
#
# A box plot is a method for graphically depicting groups of numerical
# data through their quartiles.
# The box extends from the Q1 to Q3 quartile values of the data,
# with a line at the median (Q2). The whiskers extend from the edges
# of box to show the range of the data. The position of the whiskers
# is set by default to 1.5*IQR (IQR = Q3 - Q1) from the edges of the
# box. Outlier points are those past the end of the whiskers.
#
# For further details see Wikipedia's
# entry for `boxplot <https://en.wikipedia.org/wiki/Box_plot>`__.
#
# A consideration when using this chart is that the box and the whiskers
# can overlap, which is very common when plotting small sets of data.
#
# Parameters
# ----------
# by : str or sequence
#     Column in the DataFrame to group by.
#
#     .. versionchanged:: 1.4.0
#
#        Previously, `by` is silently ignore and makes no groupings
#
# **kwargs
#     Additional keywords are documented in
#     :meth:`DataFrame.plot`.
#
# Returns
# -------
# :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#
# See Also
# --------
# DataFrame.boxplot: Another method to draw a box plot.
# Series.plot.box: Draw a box plot from a Series object.
# matplotlib.pyplot.boxplot: Draw a box plot in matplotlib.
#
# Examples
# --------
# Draw a box plot from a DataFrame with four columns of randomly
# generated data.
#
# .. plot::
#     :context: close-figs
#
#     >>> data = np.random.randn(25, 4)
#     >>> df = pd.DataFrame(data, columns=list('ABCD'))
#     >>> ax = df.plot.box()
#
# You can also generate groupings if you specify the `by` parameter (which
# can take a column name, or a list or tuple of column names):
#
# .. versionchanged:: 1.4.0
#
# .. plot::
#     :context: close-figs
#
#     >>> age_list = [8, 10, 12, 14, 72, 74, 76, 78, 20, 25, 30, 35, 60, 85]
#     >>> df = pd.DataFrame({"gender": list("MMMMMMMMFFFFFF"), "age": age_list})
#     >>> ax = df.plot.box(column="age", by="gender", figsize=(10, 8))
# File:      /opt/conda/lib/python3.10/site-packages/pandas/plotting/_core.py
# Type:      function

# %%
# pm1 -- prepandemic peak and min time of the day
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(39)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,prepandemic_day_pm1_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5, 39.5, 3), ['Day '+ str(n) for n in np.arange(1, 40,3)])
cbar.ax.set_ylabel('$PM_{1}$ (normalized)')
plt.xlabel('Hour of day')
plt.show()

# %%
# pm1 -- ecq peak and min time of the day
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(63)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,ecq_day_pm1_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
cbar.ax.set_ylabel('$PM_{1}$ (normalized)')
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5, 64, 4), ['Day '+ str(n) for n in np.arange(1, 64,4)])
plt.xlabel('Hour of day')
plt.show()

# %%
# pm1 total
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(101)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,np.vstack((prepandemic_day_pm1_df.T,ecq_day_pm1_df.T)), cmap = 'magma_r')
cbar = plt.colorbar(c)
cbar.ax.set_ylabel('$PM_{1}$ (normalized)')
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5,101.5,11), ['Day '+ str(n) for n in np.arange(1, 102,11)])
plt.show()

# %%
# pm10 -- prepandemic peak and min time of the day
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(39)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,prepandemic_day_pm10_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
cbar.ax.set_ylabel('$PM_{10}$ (normalized)')
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5, 39.5, 3), ['Day '+ str(n) for n in np.arange(1, 40,3)])
plt.show()

# %%
# pm10 -- ecq peak and min time of the day
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(63)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,ecq_day_pm10_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
cbar.ax.set_ylabel('$PM_{10}$ (normalized)')
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5, 64, 4), ['Day '+ str(n) for n in np.arange(1, 64,4)])
plt.show()

# %%
#pm10 total
x_bin = np.arange(0, (24*60*60)+1, 1)
y_bin = np.arange(101)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,np.vstack((prepandemic_day_pm10_df.T,ecq_day_pm10_df.T)), cmap = 'magma_r')
cbar = plt.colorbar(c)
cbar.ax.set_ylabel('$PM_{10}$ (normalized)')
plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
plt.yticks(np.arange(0.5,101.5,11), ['Day '+ str(n) for n in np.arange(1, 102,11)])
plt.show()

# %%
prepandemic_data_1.count()
# Out:
# pm10    54645
# pm25    54645
# pm1     54645
# dtype: int64

# %%
len(wk_end_dates)
# Out:
# 15

# %%
wk_start_dates=['2020-02-01', '2020-02-08', '2020-02-15', '2020-02-22', '2020-02-29', '2020-03-07'
                ,'2020-03-14', '2020-03-21', '2020-03-28', '2020-04-04', 
                '2020-04-11', '2020-04-18', '2020-04-25', '2020-05-03', '2020-05-11']

wk_end_dates=['2020-02-07', '2020-02-14', '2020-02-21', '2020-02-28', '2020-03-06'
                ,'2020-03-13', '2020-03-20', '2020-03-27', '2020-04-03', 
                '2020-04-10', '2020-04-17', '2020-04-24', '2020-05-02', '2020-05-10', '2020-05-17']

# %%
wk_start_dates[:5]
# Out:
# ['2020-02-01', '2020-02-08', '2020-02-15', '2020-02-22', '2020-02-29']

# %%
prepandemic_data.pm25['2020-02-01':'2020-02-07'].to_numpy()
# Out:
# array([28.7, 29. , 30.2, ..., 18.8, 18.1, 18.1])

# %%
prepandemic_data.pm25[start:end].to_numpy().shape
# Out:
# (10069,)

# %%
    
#creating dataframes such that index refer to seconds and columns refer to a particular day
prepandemic_wk_pm25_df = pd.DataFrame(columns = ['Wk_'+ str(n+1) for n in range(5)], index = np.arange(1, (7*24*60*60)+1, 1))
prepandemic_wk_pm10_df = pd.DataFrame(columns = ['Wk_'+ str(n+1) for n in range(5)], index = np.arange(1, (7*24*60*60)+1, 1))
prepandemic_wk_pm1_df = pd.DataFrame(columns = ['Wk_'+ str(n+1) for n in range(5)], index = np.arange(1, (7*24*60*60)+1, 1))


for wk_num, (start, end) in enumerate(zip(wk_start_dates[:5],wk_end_dates[:5])):
    prepandemic_wk_pm25_df['Wk_'+str(wk_num+1)] = prepandemic_data_1.pm25[start:end].to_numpy()

    
for wk_num, (start, end) in enumerate(zip(wk_start_dates[:5],wk_end_dates[:5])):
    prepandemic_wk_pm10_df['Wk_'+str(wk_num+1)] = prepandemic_data_1.pm10[start:end].to_numpy()

    
for wk_num, (start, end) in enumerate(zip(wk_start_dates[:5],wk_end_dates[:5])):
    prepandemic_wk_pm1_df['Wk_'+str(wk_num+1)] = prepandemic_data_1.pm1[start:end].to_numpy()

# %%
prepandemic_wk_pm25_df.columns
# Out:
# Index(['Wk_1', 'Wk_2', 'Wk_3', 'Wk_4', 'Wk_5'], dtype='object')

# %%
prepandemic_wk_pm25_df.describe()
# Out:
#                Wk_1          Wk_2          Wk_3          Wk_4          Wk_5
# count  10069.000000  10076.000000  10059.000000  10063.000000  10067.000000
# mean      18.026706     18.427183     13.161348     13.471818     14.119857
# std       13.750519     15.889232     10.203829      9.214588      9.906664
# min        1.100000      1.000000      1.200000      0.600000      0.800000
# 25%        8.400000      6.900000      6.200000      6.000000      6.600000
# 50%       13.600000     11.800000     10.200000     11.100000     11.200000
# 75%       23.100000     25.300000     17.200000     19.400000     19.400000
# max      145.600000     85.000000    125.200000     63.900000     75.600000

# %%
for col in prepandemic_wk_pm25_df.columns:
    min_val = prepandemic_wk_pm25_df[col].min()
    max_val = prepandemic_wk_pm25_df[col].max()
    prepandemic_wk_pm25_df[col] = prepandemic_wk_pm25_df[col].apply(lambda x: (x-min_val) / (max_val - min_val) 
                                           if pd.isnull(x) == False else np.nan)

# %%
for col in prepandemic_wk_pm25_df.columns:
    prepandemic_wk_pm25_df[col] = prepandemic_wk_pm25_df[col].apply(lambda x: (x-prepandemic_wk_pm25_df[col].min()) / (prepandemic_wk_pm25_df[col].max() - prepandemic_wk_pm25_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)
    
for col in prepandemic_wk_pm10_df.columns:
    prepandemic_wk_pm10_df[col] = prepandemic_wk_pm10_df[col].apply(lambda x: (x-prepandemic_wk_pm10_df[col].min()) / (prepandemic_wk_pm10_df[col].max() - prepandemic_wk_pm10_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)

for col in prepandemic_wk_pm1_df.columns:
    prepandemic_wk_pm1_df[col] = prepandemic_wk_pm1_df[col].apply(lambda x: (x-prepandemic_wk_pm1_df[col].min()) / (prepandemic_wk_pm1_df[col].max() - prepandemic_wk_pm1_df[col].min()) 
                                           if pd.isnull(x) == False else np.nan)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [154], in <cell line: 1>()
#       1 for col in prepandemic_wk_pm25_df.columns:
# ----> 2     prepandemic_wk_pm25_df[col] = prepandemic_wk_pm25_df[col].apply(lambda x: (x-prepandemic_wk_pm25_df[col].min()) / (prepandemic_wk_pm25_df[col].max() - prepandemic_wk_pm25_df[col].min())
#       3                                            if pd.isnull(x) == False else np.nan)
#       5 for col in prepandemic_wk_pm10_df.columns:
#       6     prepandemic_wk_pm10_df[col] = prepandemic_wk_pm10_df[col].apply(lambda x: (x-prepandemic_wk_pm10_df[col].min()) / (prepandemic_wk_pm10_df[col].max() - prepandemic_wk_pm10_df[col].min())
#       7                                            if pd.isnull(x) == False else np.nan)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [154], in <lambda>(x)
#       1 for col in prepandemic_wk_pm25_df.columns:
# ----> 2     prepandemic_wk_pm25_df[col] = prepandemic_wk_pm25_df[col].apply(lambda x: (x-prepandemic_wk_pm25_df[col].min()) / (prepandemic_wk_pm25_df[col].max() - prepandemic_wk_pm25_df[col].min())
#       3                                            if pd.isnull(x) == False else np.nan)
#       5 for col in prepandemic_wk_pm10_df.columns:
#       6     prepandemic_wk_pm10_df[col] = prepandemic_wk_pm10_df[col].apply(lambda x: (x-prepandemic_wk_pm10_df[col].min()) / (prepandemic_wk_pm10_df[col].max() - prepandemic_wk_pm10_df[col].min())
#       7                                            if pd.isnull(x) == False else np.nan)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:11237, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11217 @doc(  # type: ignore[misc]
#   11218     _num_doc,
#   11219     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11235     **kwargs,
#   11236 ):
# > 11237     return NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:10651, in NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#   10643 def min(
#   10644     self,
#   10645     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10649     **kwargs,
#   10650 ):
# > 10651     return self._stat_function(
#   10652         "min",
#   10653         nanops.nanmin,
#   10654         axis,
#   10655         skipna,
#   10656         level,
#   10657         numeric_only,
#   10658         **kwargs,
#   10659     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:10639, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10629     warnings.warn(
#   10630         "Using the level keyword in DataFrame and Series aggregations is "
#   10631         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10634         stacklevel=find_stack_level(),
#   10635     )
#   10636     return self._agg_by_level(
#   10637         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10638     )
# > 10639 return self._reduce(
#   10640     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10641 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:4471, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4467     raise NotImplementedError(
#    4468         f"Series.{name} does not implement {kwd_name}."
#    4469     )
#    4470 with np.errstate(all="ignore"):
# -> 4471     return op(delegate, skipna=skipna, **kwds)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/nanops.py:1032, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1022 @bottleneck_switch(name="nan" + meth)
#    1023 @_datetimelike_compat
#    1024 def reduction(
#    (...)
#    1029     mask: npt.NDArray[np.bool_] | None = None,
#    1030 ) -> Dtype:
# -> 1032     values, mask, dtype, dtype_max, fill_value = _get_values(
#    1033         values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1034     )
#    1036     if (axis is not None and values.shape[axis] == 0) or values.size == 0:
#    1037         try:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/nanops.py:331, in _get_values(values, skipna, fill_value, fill_value_typ, mask)
#     329 if dtype_ok or datetimelike:
#     330     values = values.copy()
# --> 331     np.putmask(values, mask, fill_value)
#     332 else:
#     333     # np.where will promote if needed
#     334     values = np.where(~mask, values, fill_value)
#
# File <__array_function__ internals>:180, in putmask(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# pm2.5 -- prepandemic peak and min in a week
x_bin = np.arange(0, (7*24*60*60)+1, 1)
y_bin = np.arange(0,6)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,prepandemic_wk_pm25_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
# plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
# plt.yticks(np.arange(0.5, 39.5, 3), ['Day '+ str(n) for n in np.arange(1, 40,3)])
cbar.ax.set_ylabel('$PM_{2.5}$ (normalized)')
plt.show()

# %%
# pm2.5 -- prepandemic peak and min in a week
x_bin = np.arange(0, (7*24*60*60)+1, 1)
y_bin = np.arange(0,6)
X, Y = np.meshgrid(x_bin, y_bin)
c = plt.pcolor(X,Y,prepandemic_wk_pm25_df.T, cmap = 'magma_r')
cbar = plt.colorbar(c)
# plt.xticks([3600*n for n in np.arange(0,24,2)], np.arange(0, 24, 2))
# plt.yticks(np.arange(0.5, 39.5, 3), ['Day '+ str(n) for n in np.arange(1, 40,3)])
cbar.ax.set_ylabel('$PM_{2.5}$ (normalized)')
plt.show()

# %%
prepandemic_wk_pm25_df.columns
# Out:
# Index(['Wk_1', 'Wk_2', 'Wk_3', 'Wk_4', 'Wk_5'], dtype='object')

# %%
prepandemic_wk_pm25_df.count()
# Out:
# Wk_1    10069
# Wk_2    10076
# Wk_3    10059
# Wk_4    10063
# Wk_5    10067
# dtype: int64

# %%
for wk_num, (start, end) in enumerate(zip(wk_start_dates,wk_end_dates)):
    print(wk_num,start, end )
# Out:
# 0 2020-02-01 2020-02-07
# 1 2020-02-08 2020-02-14
# 2 2020-02-15 2020-02-21
# 3 2020-02-22 2020-02-28
# 4 2020-02-29 2020-03-06
# 5 2020-03-07 2020-03-13
# 6 2020-03-14 2020-03-20
# 7 2020-03-21 2020-03-27
# 8 2020-03-28 2020-04-03
# 9 2020-04-04 2020-04-10
# 10 2020-04-11 2020-04-17
# 11 2020-04-18 2020-04-24
# 12 2020-04-25 2020-05-02
# 13 2020-05-03 2020-05-10
# 14 2020-05-11 2020-05-17
